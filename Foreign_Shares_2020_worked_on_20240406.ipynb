# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/first_2024/blob/main/Foreign_Shares_2020_worked_on_20240406.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import calendar
import datetime
df_usd2eur = pd.read_csv('/content/eur_usd_2020_20240329_plus_weekends.csv')
df_usd2eur
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 0     01/01/2020  1.122083  1.122838  1.115947  1.122083   1.122083       0
# 1     02/01/2020  1.121894  1.122712  1.116682  1.122083   1.122083       0
# 2     03/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# 3     04/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# 4     05/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# ...          ...       ...       ...       ...       ...        ...     ...
# 1545  25/03/2024  1.080754  1.084363  1.080264  1.080754   1.080754       0
# 1546  26/03/2024  1.083823  1.086413  1.082603  1.083823   1.083823       0
# 1547  27/03/2024  1.083236  1.083929  1.081175  1.083236   1.083236       0
# 1548  28/03/2024  1.081338  1.082837  1.077551  1.081338   1.081338       0
# 1549  29/03/2024  1.079447  1.080731  1.076890  1.079447   1.079447       0
#
#         Weekday
# 0     Wednesday
# 1      Thursday
# ...

# %%
df_usd2eur.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# Weekday       object
# dtype: object

# %%
df_usd2eur['Date_datetime'] = pd.to_datetime(df_usd2eur['Date'],dayfirst=True)

# %%
df_usd2eur
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 0     01/01/2020  1.122083  1.122838  1.115947  1.122083   1.122083       0
# 1     02/01/2020  1.121894  1.122712  1.116682  1.122083   1.122083       0
# 2     03/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# 3     04/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# 4     05/01/2020  1.117081  1.118068  1.112570  1.117144   1.117144       0
# ...          ...       ...       ...       ...       ...        ...     ...
# 1545  25/03/2024  1.080754  1.084363  1.080264  1.080754   1.080754       0
# 1546  26/03/2024  1.083823  1.086413  1.082603  1.083823   1.083823       0
# 1547  27/03/2024  1.083236  1.083929  1.081175  1.083236   1.083236       0
# 1548  28/03/2024  1.081338  1.082837  1.077551  1.081338   1.081338       0
# 1549  29/03/2024  1.079447  1.080731  1.076890  1.079447   1.079447       0
#
#         Weekday Date_datetime
# ...

# %%
df_usd2eur.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Close                   float64
# Adj Close               float64
# Volume                    int64
# Weekday                  object
# Date_datetime    datetime64[ns]
# dtype: object

# %%
#Rename column names by adding '_Eur' on each column name
df_usd2eur.rename(columns=lambda x: x + '_Eur', inplace=True)
df_usd2eur
# Out:
#         Date_Eur  Open_Eur  High_Eur   Low_Eur  Close_Eur  Adj Close_Eur  \
# 0     01/01/2020  1.122083  1.122838  1.115947   1.122083       1.122083
# 1     02/01/2020  1.121894  1.122712  1.116682   1.122083       1.122083
# 2     03/01/2020  1.117081  1.118068  1.112570   1.117144       1.117144
# 3     04/01/2020  1.117081  1.118068  1.112570   1.117144       1.117144
# 4     05/01/2020  1.117081  1.118068  1.112570   1.117144       1.117144
# ...          ...       ...       ...       ...        ...            ...
# 1545  25/03/2024  1.080754  1.084363  1.080264   1.080754       1.080754
# 1546  26/03/2024  1.083823  1.086413  1.082603   1.083823       1.083823
# 1547  27/03/2024  1.083236  1.083929  1.081175   1.083236       1.083236
# 1548  28/03/2024  1.081338  1.082837  1.077551   1.081338       1.081338
# 1549  29/03/2024  1.079447  1.080731  1.076890   1.079447       1.079447
#
#       Volume_Eur Weekday_Eur Date_datetime_Eur
# ...

# %%
et_2020_closed_position = pd.read_excel('/content/etoro-account-statement-1-1-2020-12-31-2020_DwnLd20230201.xlsx',sheet_name=1)

# %%
et_2020_closed_position
# Out:
#       Position ID                         Action  Amount     Units  \
# 0       856095290                  Sell Ethereum  200.00  0.266455
# 1       848528801        Sell Tesla Motors, Inc.  129.83  1.000000
# 2       847006198        Sell Tesla Motors, Inc.  110.00  0.871480
# 3       845829079         Buy Meta Platforms Inc  100.00  1.875610
# 4       845839951         Buy Meta Platforms Inc  100.00  1.870487
# ...           ...                            ...     ...       ...
# 1232    599925854             Buy Amazon.com Inc   50.00  0.021224
# 1233    599947206  Buy Occidental Petroleum Corp  100.00  7.496252
# 1234    602587134                  Buy Microsoft   50.00  0.299473
# 1235    601099709                 Buy Block Inc.  200.00  3.186743
# 1236    599924729                      Buy Apple  100.00  0.355973
#
#                 Open Date           Close Date  Leverage  Spread  Profit  \
# 0     30/12/2020 20:01:10  31/12/2020 22:31:48         1    3.74    0.12
# ...

# %%
# Make new columns for open date, open time, close date, close time
et_2020_closed_position['Open Date_wo_time'] = et_2020_closed_position['Open Date'].map(lambda x: x.split(' ')[0])
et_2020_closed_position['Open time'] = et_2020_closed_position['Open Date'].map(lambda x: x.split(' ')[1])
et_2020_closed_position['Close Date_wo_time'] = et_2020_closed_position['Close Date'].map(lambda x: x.split(' ')[0])
et_2020_closed_position['Close time'] = et_2020_closed_position['Close Date'].map(lambda x: x.split(' ')[1])

# %%
et_2020_closed_position['Open Date_wo_time']= pd.to_datetime(et_2020_closed_position['Open Date_wo_time'],dayfirst=True)
et_2020_closed_position['Close Date_wo_time']= pd.to_datetime(et_2020_closed_position['Close Date_wo_time'],dayfirst=True)

# %%
et_2020_closed_position.dtypes
# Out:
# Position ID                             int64
# Action                                 object
# Amount                                float64
# Units                                 float64
# Open Date                              object
# Close Date                             object
# Leverage                                int64
# Spread                                float64
# Profit                                float64
# Open Rate                             float64
# Close Rate                            float64
# Take profit rate                      float64
# Stop lose rate                        float64
# Rollover Fees and Dividends           float64
# Copied From                            object
# Type                                   object
# ISIN                                   object
# Notes                                 float64
# Open Date_wo_time              datetime64[ns]
# Open time                              object
# ...

# %%
et_2020_closed_position['Type'].value_counts()
# Out:
# Type
# CFD              444
# Stocks           442
# Crypto           344
# Crypto Margin      7
# Name: count, dtype: int64

# %%
et_2020_closed_position[et_2020_closed_position['Type'].isin(['Stocks'])]['Type'].value_counts()
# Out:
# Type
# Stocks    442
# Name: count, dtype: int64

# %%
# Filter the transactions to get 'stocks' in one place
df_stocks = et_2020_closed_position[et_2020_closed_position['Type'].isin(['Stocks'])]

# %%
df_stocks['Type'].value_counts()
# Out:
# Type
# Stocks    442
# Name: count, dtype: int64

# %%
df_stocks.columns
# Out:
# Index(['Position ID', 'Action', 'Amount', 'Units', 'Open Date', 'Close Date',
#        'Leverage', 'Spread', 'Profit', 'Open Rate', 'Close Rate',
#        'Take profit rate', 'Stop lose rate', 'Rollover Fees and Dividends',
#        'Copied From', 'Type', 'ISIN', 'Notes', 'Open Date_wo_time',
#        'Open time', 'Close Date_wo_time', 'Close time'],
#       dtype='object')

# %%
df_stocks['Action'].unique()
# Out:
# array(['Buy Tesla Motors, Inc.', 'Buy Meta Platforms Inc', 'Buy Apple',
#        'Buy Alibaba-ADR', 'Buy Lemonade Inc.', 'Buy Amazon.com Inc',
#        'Buy Palantir Technologies Inc.', 'Buy Block Inc.',
#        'Buy Unity Software Inc.', 'Buy Advanced Micro Devices Inc',
#        'Buy Invitae Corp', 'Buy Tencent',
#        'Buy Virgin Galactic Holdings Inc', 'Buy RingCentral Inc',
#        'Buy Okta Inc', 'Buy Microsoft', 'Buy NVIDIA Corporation',
#        'Buy Netflix, Inc.', 'Buy Fastly Inc', 'Buy Shopify Inc.',
#        'Buy PayPal Holdings', 'Buy Walmart Inc.',
#        'Buy Peloton Interactive', 'Buy Zillow Group Inc',
#        'Buy Beyond Meat Inc.', 'Buy Spotify Technologies SA',
#        'Buy Nio Inc.-ADR', 'Buy Alphabet', 'Buy Box Inc',
#        'Buy Cirrus Logic Inc', 'Buy Crowdstrike Holdings', 'Buy Illumina',
#        'Buy TUI AG', 'Buy Activision Blizzard, Inc.', 'Buy Boeing',
#        'Buy Delta Air Lines Inc (DE)', 'Buy Western Digital Corporation',
# ...

# %%
df_stocks['Action'].value_counts()
# Out:
# Action
# Buy Tesla Motors, Inc.                          120
# Buy Block Inc.                                   40
# Buy TUI AG                                       40
# Buy Norwegian Cruise Line Holdings               35
# Buy Carnival Corp                                25
# Buy Delta Air Lines Inc (DE)                     25
# Buy Meta Platforms Inc                           18
# Buy Boeing                                       15
# Buy Under Armour                                 11
# Buy Deutsche Lufthansa Aktiengesellschaft        10
# Buy Occidental Petroleum Corp                    10
# Buy Western Digital Corporation                   7
# Buy Alibaba-ADR                                   6
# Buy Amazon.com Inc                                6
# Buy Aston Martin Lagonda Global Holdings PLC      6
# Buy Microsoft                                     6
# Buy Alphabet                                      5
# Buy Palantir Technologies Inc.                    5
# ...

# %%
df_stocks_usd = df_stocks[df_stocks['Action'].isin(
    [
      'Buy Tesla Motors, Inc.', 'Buy Meta Platforms Inc', 'Buy Apple',
       'Buy Alibaba-ADR', 'Buy Lemonade Inc.', 'Buy Amazon.com Inc',
       'Buy Palantir Technologies Inc.', 'Buy Block Inc.',
       'Buy Unity Software Inc.', 'Buy Advanced Micro Devices Inc',
       'Buy Invitae Corp',
       'Buy Virgin Galactic Holdings Inc', 'Buy RingCentral Inc',
       'Buy Okta Inc', 'Buy Microsoft', 'Buy NVIDIA Corporation',
       'Buy Netflix, Inc.', 'Buy Fastly Inc', 'Buy Shopify Inc.',
       'Buy PayPal Holdings', 'Buy Walmart Inc.',
       'Buy Peloton Interactive', 'Buy Zillow Group Inc',
       'Buy Beyond Meat Inc.', 'Buy Spotify Technologies SA',
       'Buy Nio Inc.-ADR', 'Buy Alphabet', 'Buy Box Inc',
       'Buy Cirrus Logic Inc', 'Buy Crowdstrike Holdings', 'Buy Illumina',
       'Buy Activision Blizzard, Inc.', 'Buy Boeing',
       'Buy Delta Air Lines Inc (DE)', 'Buy Western Digital Corporation',
       'Buy Carnival Corp', 'Buy Norwegian Cruise Line Holdings',
       'Buy Costco Wholesale Corp', 'Buy Coca-Cola', 'Buy Under Armour',
       'Buy JD.com-ADR',
       'Buy Occidental Petroleum Corp', 'Buy Chesapeake Energy Corp',
       ])]

# %%
df_stocks
# Out:
#       Position ID                         Action   Amount     Units  \
# 795     847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 796     846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 797     727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 798     845838192         Buy Meta Platforms Inc   100.00  0.374546
# 799     843250255                      Buy Apple  1000.00  8.048938
# ...           ...                            ...      ...       ...
# 1232    599925854             Buy Amazon.com Inc    50.00  0.021224
# 1233    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 1234    602587134                  Buy Microsoft    50.00  0.299473
# 1235    601099709                 Buy Block Inc.   200.00  3.186743
# 1236    599924729                      Buy Apple   100.00  0.355973
#
#                 Open Date           Close Date  Leverage  Spread  Profit  \
# 795   23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd
# Out:
#       Position ID                         Action   Amount     Units  \
# 795     847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 796     846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 797     727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 798     845838192         Buy Meta Platforms Inc   100.00  0.374546
# 799     843250255                      Buy Apple  1000.00  8.048938
# ...           ...                            ...      ...       ...
# 1232    599925854             Buy Amazon.com Inc    50.00  0.021224
# 1233    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 1234    602587134                  Buy Microsoft    50.00  0.299473
# 1235    601099709                 Buy Block Inc.   200.00  3.186743
# 1236    599924729                      Buy Apple   100.00  0.355973
#
#                 Open Date           Close Date  Leverage  Spread  Profit  \
# 795   23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd.dtypes
# Out:
# Position ID                             int64
# Action                                 object
# Amount                                float64
# Units                                 float64
# Open Date                              object
# Close Date                             object
# Leverage                                int64
# Spread                                float64
# Profit                                float64
# Open Rate                             float64
# Close Rate                            float64
# Take profit rate                      float64
# Stop lose rate                        float64
# Rollover Fees and Dividends           float64
# Copied From                            object
# Type                                   object
# ISIN                                   object
# Notes                                 float64
# Open Date_wo_time              datetime64[ns]
# Open time                              object
# ...

# %%
df_stocks_usd.columns
# Out:
# Index(['Position ID', 'Action', 'Amount', 'Units', 'Open Date', 'Close Date',
#        'Leverage', 'Spread', 'Profit', 'Open Rate', 'Close Rate',
#        'Take profit rate', 'Stop lose rate', 'Rollover Fees and Dividends',
#        'Copied From', 'Type', 'ISIN', 'Notes', 'Open Date_wo_time',
#        'Open time', 'Close Date_wo_time', 'Close time'],
#       dtype='object')

# %%
df_usd2eur.columns
# Out:
# Index(['Date_Eur', 'Open_Eur', 'High_Eur', 'Low_Eur', 'Close_Eur',
#        'Adj Close_Eur', 'Volume_Eur', 'Weekday_Eur', 'Date_datetime_Eur'],
#       dtype='object')

# %%
# Let's merge for open date and so we can get eur conversion for open date
# Merge the dataframes based on the 'Date' column
merged_df = pd.merge(df1, df2[['df2_date', 'Other_Value']], left_on='df1_date', right_on='df2_date', how='left')
# Rename the column
merged_df.rename(columns={'Other_Value': 'merged_Other_Value'}, inplace=True)

# %%
df_stocks_usd_openEur = pd.merge(df_stocks_usd, df_usd2eur[['Date_datetime_Eur', 'Open_Eur']], left_on='Open Date_wo_time', right_on='Date_datetime_Eur', how='left')

# %%
df_stocks_usd_openEur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
# Rename the columns
df_stocks_usd_openEur.rename(columns={
    'Open_Eur': 'Open_position eur_rate Open_Eur',
    'Date_datetime_Eur': 'Open_position Date_datetime_Eur'
    }, inplace=True)

# %%
df_stocks_usd_openEur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd_openEur.columns
# Out:
# Index(['Position ID', 'Action', 'Amount', 'Units', 'Open Date', 'Close Date',
#        'Leverage', 'Spread', 'Profit', 'Open Rate', 'Close Rate',
#        'Take profit rate', 'Stop lose rate', 'Rollover Fees and Dividends',
#        'Copied From', 'Type', 'ISIN', 'Notes', 'Open Date_wo_time',
#        'Open time', 'Close Date_wo_time', 'Close time',
#        'Open_position Date_datetime_Eur', 'Open_position eur_rate Open_Eur'],
#       dtype='object')

# %%
df_usd2eur.columns
# Out:
# Index(['Date_Eur', 'Open_Eur', 'High_Eur', 'Low_Eur', 'Close_Eur',
#        'Adj Close_Eur', 'Volume_Eur', 'Weekday_Eur', 'Date_datetime_Eur'],
#       dtype='object')

# %%
# Let's merge for close date and so we can get open_eur conversion for close date

# %%
df_stocks_usd_open_close_Eur = pd.merge(df_stocks_usd_openEur, df_usd2eur[['Date_datetime_Eur', 'Open_Eur']], left_on='Close Date_wo_time', right_on='Date_datetime_Eur', how='left')

# %%
df_stocks_usd_open_close_Eur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
# Rename the columns
df_stocks_usd_open_close_Eur.rename(columns={
    'Open_Eur': 'Close_position eur_rate Open_Eur',
    'Date_datetime_Eur': 'Close_position Date_datetime_Eur'
    }, inplace=True)

# %%
df_stocks_usd_open_close_Eur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd_open_close_Eur.drop(['ISIN', 'Notes'], axis=1, inplace=True)

# %%
df_stocks_usd_open_close_Eur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd_open_close_Eur.columns
# Out:
# Index(['Position ID', 'Action', 'Amount', 'Units', 'Open Date', 'Close Date',
#        'Leverage', 'Spread', 'Profit', 'Open Rate', 'Close Rate',
#        'Take profit rate', 'Stop lose rate', 'Rollover Fees and Dividends',
#        'Copied From', 'Type', 'Open Date_wo_time', 'Open time',
#        'Close Date_wo_time', 'Close time', 'Open_position Date_datetime_Eur',
#        'Open_position eur_rate Open_Eur', 'Close_position Date_datetime_Eur',
#        'Close_position eur_rate Open_Eur'],
#       dtype='object')

# %%
df_stocks_usd_open_close_Eur['Open_Amount_Eur'] = df_stocks_usd_open_close_Eur['Amount'] / df_stocks_usd_open_close_Eur['Open_position eur_rate Open_Eur']

# %%
df_stocks_usd_open_close_Eur['Close_Amount_USD'] = df_stocks_usd_open_close_Eur['Amount'] + df_stocks_usd_open_close_Eur['Profit']

# %%
df_stocks_usd_open_close_Eur['Close_Amount_Eur'] = (df_stocks_usd_open_close_Eur['Close_Amount_USD'] + df_stocks_usd_open_close_Eur['Rollover Fees and Dividends']) / df_stocks_usd_open_close_Eur['Close_position eur_rate Open_Eur']

# %%
df_stocks_usd_open_close_Eur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
df_stocks_usd_open_close_Eur['Profit_Eur'] = df_stocks_usd_open_close_Eur['Close_Amount_Eur'] - df_stocks_usd_open_close_Eur['Open_Amount_Eur']

# %%
df_stocks_usd_open_close_Eur
# Out:
#      Position ID                         Action   Amount     Units  \
# 0      847158900         Buy Tesla Motors, Inc.   376.42  1.000000
# 1      846972659         Buy Tesla Motors, Inc.   376.42  1.000000
# 2      727408178         Buy Tesla Motors, Inc.   100.00  0.261808
# 3      845838192         Buy Meta Platforms Inc   100.00  0.374546
# 4      843250255                      Buy Apple  1000.00  8.048938
# ..           ...                            ...      ...       ...
# 379    599925854             Buy Amazon.com Inc    50.00  0.021224
# 380    599947206  Buy Occidental Petroleum Corp   100.00  7.496252
# 381    602587134                  Buy Microsoft    50.00  0.299473
# 382    601099709                 Buy Block Inc.   200.00  3.186743
# 383    599924729                      Buy Apple   100.00  0.355973
#
#                Open Date           Close Date  Leverage  Spread  Profit  \
# 0    23/09/2020 19:05:47  23/12/2020 15:37:19         1     0.0  273.14
# ...

# %%
# Filter rows where 'Profit' is negative
df_loss = df[df['Profit'] < 0]

# Filter rows where 'Profit' is non-negative
df_profit = df[df['Profit'] >= 0]

# %%
df_stocksusd_profit = df_stocks_usd_open_close_Eur[df_stocks_usd_open_close_Eur['Profit_Eur'] >= 0]

# %%
df_stocksusd_profit['Profit_Eur'].sum()
# Out:
# 4646.846038491906

# %%
df_stocksusd_loss = df_stocks_usd_open_close_Eur[df_stocks_usd_open_close_Eur['Profit_Eur'] < 0]

# %%
df_stocksusd_loss['Profit_Eur'].sum()
# Out:
# -1540.2392538910929

# %%
df_stocks_usd_open_close_Eur['Profit_Eur'].sum()
# Out:
# 3106.6067846008136

# %%
df_stocksusd_loss.to_csv('stocksusd_loss_eur_2020.csv',index=False)

# %%
df_stocksusd_profit.to_csv('stocksusd_profit_eur_2020.csv',index=False)

# %%
df_stocks_usd_open_close_Eur.to_csv('stocksusd_eur_2020.csv',index=False)

# %%
df_stocks_usd_open_close_Eur['Action'].value_counts()
# Out:
# Action
# Buy Tesla Motors, Inc.                120
# Buy Block Inc.                         40
# Buy Norwegian Cruise Line Holdings     35
# Buy Carnival Corp                      25
# Buy Delta Air Lines Inc (DE)           25
# Buy Meta Platforms Inc                 18
# Buy Boeing                             15
# Buy Under Armour                       11
# Buy Occidental Petroleum Corp          10
# Buy Western Digital Corporation         7
# Buy Alibaba-ADR                         6
# Buy Amazon.com Inc                      6
# Buy Microsoft                           6
# Buy Apple                               5
# Buy Palantir Technologies Inc.          5
# Buy Alphabet                            5
# Buy Peloton Interactive                 4
# Buy Illumina                            3
# Buy Lemonade Inc.                       3
# Buy Netflix, Inc.                       3
# Buy Spotify Technologies SA             3
# Buy Unity Software Inc.                 2
# ...

# %%
df_find_na = df_stocks_usd_open_close_Eur # use the DataFrame for which you would like to find NANs
columns_df_find_na = df_find_na.columns
def find_null_values(column_name):
  print('The number of null values in column {} are:'.format(column_name),len(np.where(df_find_na.isna()[column_name])[0]))
  print('And their integer location is:', np.where(df_find_na.isna()[column_name])[0])
null_values = [find_null_values(y) for y in columns_df_find_na]
# Out:
# The number of null values in column Position ID are: 0
# And their integer location is: []
# The number of null values in column Action are: 0
# And their integer location is: []
# The number of null values in column Amount are: 0
# And their integer location is: []
# The number of null values in column Units are: 0
# And their integer location is: []
# The number of null values in column Open Date are: 0
# And their integer location is: []
# The number of null values in column Close Date are: 0
# And their integer location is: []
# The number of null values in column Leverage are: 0
# And their integer location is: []
# The number of null values in column Spread are: 0
# And their integer location is: []
# The number of null values in column Profit are: 0
# And their integer location is: []
# The number of null values in column Open Rate are: 0
# And their integer location is: []
# The number of null values in column Close Rate are: 0
# And their integer location is: []
# ...
